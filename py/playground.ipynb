# %%
import numpy as np
from scipy.signal import welch
import matplotlib.pyplot as plt

# Generate a sample signal
fs = 100  # Sampling frequency (Hz)
t = 300  # Duration (seconds)
signal = np.random.randn(fs * t)  # Replace with actual signal data

# Compute PSD using Welch's method
frequencies, psd = welch(signal, fs, nperseg=1024)

# Save PSD data to a file
np.save('psd_data.npy', psd)

# Plot the PSD
plt.semilogy(frequencies, psd)
plt.xlabel('Frequency (Hz)')
plt.ylabel('PSD (V^2/Hz)')
plt.title('Power Spectral Density')
plt.show()

# %%
psd_data = np.load('psd_data.npy')
